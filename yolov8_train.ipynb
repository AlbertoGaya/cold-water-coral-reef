# %%
# !nvidia-smi
# Out:
# Mon May 27 09:29:57 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.171.04             Driver Version: 535.171.04   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060        Off | 00000000:0A:00.0  On |                  N/A |
# |  0%   35C    P8               9W / 170W |    364MiB / 12288MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12036MiB)
# Setup complete ✅ (32 CPUs, 31.2 GB RAM, 625.1/3666.0 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ### Entrenamiento

# %%
# !yolo train data=label.yaml model=yolov8l-seg.pt epochs=500 lr0=0.01 #batch=4
# Out:
# New https://pypi.org/project/ultralytics/8.2.22 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12036MiB)
# ...

# %% [markdown]
# ### Inferencia

# %%
# !yolo predict model=runs/segment/train13/weights/best.pt source='IC222_TF05' imgsz=640 conf=0.5 save_txt=True
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12036MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45912659 parameters, 0 gradients, 220.1 GFLOPs
#
# image 1/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1625.JPG: 448x640 7 Dead Corals, 182.8ms
# image 2/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1626.JPG: 448x640 10 Dead Corals, 23.2ms
# image 3/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1627.JPG: 448x640 7 Dead Corals, 22.8ms
# image 4/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1628.JPG: 448x640 7 Dead Corals, 22.6ms
# image 5/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1629.JPG: 448x640 7 Dead Corals, 23.1ms
# image 6/108 /home/berto/Documents/iMagine/YOLO-seg/Train/IC222_TF05/IC222_TF05_1630.JPG: 448x640 10 Dead Corals, 23.7ms
# ...

# %% [markdown]
# ### Validación

# %%
# !yolo val model=runs/segment/train14/weights/best.pt data=label.yaml batch=1 imgsz=640
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060, 12036MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45913430 parameters, 0 gradients, 220.1 GFLOPs
# val: Scanning /home/berto/Documents/iMagine/YOLO-seg/Train/datasets/val/labels.c
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         27        270      0.808      0.737      0.804       0.58      0.791       0.72      0.777      0.541
#      Madrepora oculata         27        104      0.751      0.663      0.728       0.51       0.73      0.644      0.694      0.466
#  Desmophyllum pertusum         27        166      0.865       0.81       0.88      0.649      0.852      0.796      0.861      0.615
# Speed: 0.4ms preprocess, 29.7ms inference, 0.0ms loss, 26.0ms postprocess per image
# Results saved to runs/segment/val7
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.0335, 0.3958, 0.0306],
#         [0.5246, 0.7164, 0.3197],
#         [0.0671, 0.4893, 0.6511],
#         [0.7904, 0.2123, 0.5788],
#         [0.2926, 0.3127, 0.6761]])

# %%
import os

# Ruta de la carpeta que contiene las imágenes
carpeta_imagenes = "IC222_TF18"

# Obtener una lista de nombres de archivos en la carpeta
nombres_archivos = os.listdir(carpeta_imagenes)

# Ruta para el archivo de texto donde se escribirán los nombres
archivo_txt = "nombres_imagenes.txt"

# Escribir los nombres de los archivos en el archivo de texto
with open(archivo_txt, 'w') as archivo:
    for nombre in nombres_archivos:
        archivo.write(nombre + '\n')

print("Se ha creado el archivo", archivo_txt)
# Out:
# Se ha creado el archivo nombres_imagenes.txt

# %%
# Ruta del archivo que contiene los nombres de las imágenes
archivo_nombres_imagenes = "nombres_imagenes.txt"

# Leer el contenido del archivo y eliminar ".JPG" de cada línea, reemplazándolo por ".txt"
with open(archivo_nombres_imagenes, 'r') as f:
    nombres_imagenes = [line.strip().replace('.JPG', '.txt') for line in f]

# Iterar sobre cada nombre de imagen y crear un archivo de texto con ese nombre
for nombre_imagen in nombres_imagenes:
    # Crear el archivo .txt
    with open(nombre_imagen, 'w') as f:
        pass  # No necesitamos escribir contenido en este momento

print("Se han creado los archivos .txt según los nombres de imágenes proporcionados en el archivo.")
# Out:
# Se han creado los archivos .txt según los nombres de imágenes proporcionados en el archivo.

# %%
import os
import re
import shutil

def copiar_imagenes_impares(origen, destino):
    # Obtener la lista de archivos en la carpeta de origen
    archivos = os.listdir(origen)
    
    # Crear la carpeta de destino con el nombre original más '_pair'
    carpeta_destino = destino + "_pair"
    os.makedirs(carpeta_destino, exist_ok=True)

    # Recorrer todos los archivos en la carpeta de origen
    for archivo in archivos:
        # Verificar si el archivo es una imagen JPG
        if archivo.lower().endswith(".jpg"):
            # Utilizar expresión regular para extraer el número del nombre del archivo
            match = re.search(r'A0410_TF09_(\d+)\.JPG', archivo)
            if match:
                numero_archivo = int(match.group(1))
                
                # Verificar si el número de archivo es impar
                if numero_archivo % 2 != 0:
                    # Copiar el archivo a la carpeta de destino
                    shutil.copy(os.path.join(origen, archivo), carpeta_destino)
                    print(f"Imagen impar {archivo} copiada a {carpeta_destino}")

# Ejemplo de uso
carpeta_origen = "A0410_TF09"
carpeta_destino = os.path.basename(carpeta_origen)  # Usar el mismo nombre que la carpeta original

copiar_imagenes_impares(carpeta_origen, carpeta_destino)
# Out:
# Imagen impar A0410_TF09_3613.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3585.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3545.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3547.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3501.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3529.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3541.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3455.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3509.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3623.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3559.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3575.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3533.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3503.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3555.JPG copiada a A0410_TF09_pair
# Imagen impar A0410_TF09_3571.JPG copiada a A0410_TF09_pair
# ...

# %%
# !ls IC222_TF05
# Out:
# IC222_TF05_1625.JPG  IC222_TF05_1775.JPG  IC222_TF05_2357.JPG
# IC222_TF05_1626.JPG  IC222_TF05_1967.JPG  IC222_TF05_2364.JPG
# IC222_TF05_1627.JPG  IC222_TF05_1968.JPG  IC222_TF05_2365.JPG
# IC222_TF05_1628.JPG  IC222_TF05_1969.JPG  IC222_TF05_2366.JPG
# IC222_TF05_1629.JPG  IC222_TF05_1970.JPG  IC222_TF05_2367.JPG
# IC222_TF05_1630.JPG  IC222_TF05_1971.JPG  IC222_TF05_2368.JPG
# IC222_TF05_1631.JPG  IC222_TF05_1972.JPG  IC222_TF05_2369.JPG
# IC222_TF05_1632.JPG  IC222_TF05_1973.JPG  IC222_TF05_2370.JPG
# IC222_TF05_1633.JPG  IC222_TF05_1974.JPG  IC222_TF05_2371.JPG
# IC222_TF05_1634.JPG  IC222_TF05_1975.JPG  IC222_TF05_2372.JPG
# IC222_TF05_1635.JPG  IC222_TF05_1976.JPG  IC222_TF05_2373.JPG
# IC222_TF05_1636.JPG  IC222_TF05_1977.JPG  IC222_TF05_2374.JPG
# IC222_TF05_1637.JPG  IC222_TF05_1978.JPG  IC222_TF05_2375.JPG
# IC222_TF05_1638.JPG  IC222_TF05_1979.JPG  IC222_TF05_2376.JPG
# IC222_TF05_1639.JPG  IC222_TF05_1980.JPG  IC222_TF05_2446.JPG
# ...
